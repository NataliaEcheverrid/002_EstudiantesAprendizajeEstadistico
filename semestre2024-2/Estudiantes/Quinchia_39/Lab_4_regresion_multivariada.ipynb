# %% [markdown]
# <a href="https://colab.research.google.com/github/CienciaDatosUdea/002_EstudiantesAprendizajeEstadistico/blob/main/semestre2024-2/Laboratorios/Laboratorio_04_reg_multivariada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regresion multivariada
#
# Supongamos que tenemos un conjunto de caracteristicas $X = X_1,X_2...X_j...X_n$ para realizar una  predicción $y$ con valores esperados $\hat{y}$.
#
# Cada X, puede ser escrito como:
#  $X_1 = x_1^{(1)},x_1^{(2)}, x_1^{(3)}...x_1^{(m)}$,
#
#  $X_2 = x_2^{(1)},x_2^{(2)}, x_2^{(3)}...x_2^{(m)}$,
#
#  .
#
#  .
#
#  .
#
#  $X_n = x_n^{(1)},x_n^{(2)}, x_n^{(3)}...x_n^{(m)}$.
#
#
# Siendo n el número de caracteristicas y m el número de datos,
# $\hat{y} = \hat{y}_1^{(1)}, \hat{y}_1^{(2)}...\hat{y}_1^{(m)} $, el conjunto de datos etiquetados  y $y = y_1^{(1)}, y_1^{(2)}...y_1^{(m)} $ los valores predichos por un modelo
#
#
#
#
# Lo anterior puede ser resumido  como:
#
#
#
# |Training|$\hat{y}$      | X_1  | X_2  |  .  | .|. |. | X_n|
# |--------|-------|------|------|-----|--|--|--|----|
# |1|$\hat{y}_1^{1}$ | $x_1^{1}$|$x_2^{1}$| .  | .|. |. | $x_n^{1}$|
# |2|$\hat{y}_1^{2}$ | $x_1^{2}$|$x_2^{2}$| .  | .|. |. | $x_n^{2}$|
# |.|.         | .        |.| .  | .|. |. | |
# |.|.         | .        |.| .  | .|. |. | |
# |.|.         | .        |.| .  | .|. |. | |
# |m|$\hat{y}_1^{m}$ | $x_1^{m}$  |$x_2^{m}$| .  | .|. |. | $x_n^{m}$|
#
#
# y el modelo puede ser ajustado como sigue:
#
# Para un solo conjunto de datos de entrenamiento tentemos que:
#
# $y = h(\theta_0,\theta_1,\theta_2,...,\theta_n ) = \theta_0 + \theta_1 x_1+\theta_2 x_2 + \theta_3 x_3 +...+ \theta_n x_n $.
#
# \begin{equation}
# h_{\Theta}(x) = [\theta_0,\theta_1,...,\theta_n ]\begin{bmatrix}
# 1^{(1)}\\
# x_1^{(1)}\\
# x_2^{(1)}\\
# .\\
# .\\
# .\\
# x_n^{(1)}\\
# \end{bmatrix} = \Theta^T X^{(1)}
# \end{equation}
#
#
#
# Para todo el conjunto de datos, tenemos que:
#
# Sea $\Theta^T = [\theta_0,\theta_1,\theta_2,...,\theta_n]$ una matrix $1 \times (n+1)$ y
#
#
# \begin{equation}
# X =
# \begin{bmatrix}
# 1& 1 & 1 & .&.&.&1\\
# x_1^{(1)}&x_1^{(2)} & x_1^{(3)} & .&.&.&x_1^{(m)}\\
# .&. & . &.&.&.& .\\
# .&. & . & .&.&.&.\\
# .&. & . & .&.&.&.\\
# x_n^{(1)}&x_n^{(2)} & x^{(3)} & .&.&.&x_n^{(m)}\\
# \end{bmatrix}_{(n+1) \times m}
# \end{equation}
#
#
#
#
# luego $h = \Theta^{T} X $ con dimension $1\times m$
#
#
#
#
# La anterior ecuación, es un hiperplano en $\mathbb{R}^n$. Notese que en caso de tener una sola característica, la ecuación puede ser análizada según lo visto en la sesión de regresion lineal.
#
#
# Para la optimización, vamos a definir la función de coste **$J(\theta_1,\theta_2,\theta_3, ...,\theta_n )$** , como la función  asociada a la minima distancia entre dos puntos, según la metrica euclidiana.
#
# - Metrica Eculidiana
#
# \begin{equation}
# J(\theta_1,\theta_2,\theta_3, ...,\theta_n )=\frac{1}{2m} \sum_{i=1}^m ( h_{\Theta} (X)-\hat{y}^{(i)})^2 =\frac{1}{2m} \sum_{i = 1}^m (\Theta^{T} X - \hat{y}^{(i)})^2
# \end{equation}
#
# Otras métricas pueden ser definidas como sigue en la siguiente referencia.  [Métricas](https://jmlb.github.io/flashcards/2018/04/21/list_cost_functions_fo_neuralnets/).
#
# Nuestro objetivo será encontrar los valores mínimos
# $\Theta = \theta_0,\theta_1,\theta_2,...,\theta_n$ que minimizan el error, respecto a los valores etiquetados y esperados $\hat{y}$
#
#
# Para encontrar $\Theta$ óptimo, se necesita  minimizar la función de coste, que permite obtener los valores más cercanos, esta minimización podrá ser realizada a través de diferentes métodos, el más conocido es el gradiente descendente.

# %% [markdown]
# ## Gradiente descendente
#
# Consideremos la función de coste sin realizar el promedio  de funcion de coste:
# \begin{equation}
# \Lambda^T =
# \begin{bmatrix}
# (\theta_0 1 + \theta_1 x_1^1+\theta_2 x_2^1 + \theta_3 x_3^1 +...+ \theta_n x_n^1 - \hat{y}^{1})^2 \\
# (\theta_0 1+ \theta_1 x_1^2+\theta_2 x_2^2 + \theta_3 x_3^2 +...+ \theta_n x_n^2 - \hat{y}^{2})^2\\
# .\\
# .\\
# .\\
# (\theta_0 1 + \theta_1 x_1^m+\theta_2 x_2^m + \theta_3 x_3^m +...+ \theta_n x_n^m - \hat{y}^{m})^2\\
# \end{bmatrix}
# \end{equation}
#
# $\Lambda= [\Lambda_1,\Lambda_2, ...,\Lambda_m], \quad \Lambda_i = (\sum_j^n \theta_j X_j^i - \hat{y}^i)^2$
#
# $J = \frac{1}{2m} \sum_{i}^m \Lambda_i $
#
# El gradiente descente, puede ser escrito como:
#
# \begin{equation}
# \Delta \vec{\Theta} =  - \alpha \nabla J(\theta_0, \theta_1,...,\theta_n)
# \end{equation}
#
# escogiendo el valor j-esimo tenemos que:
#
# \begin{equation}
# \theta_j :=  - \alpha \frac{\partial J(\theta_0, \theta_1,...\theta_j...,\theta_n)}{\partial \theta_j}
# \end{equation}
#
# Aplicando lo anterior a la función de coste asociada a la métrica euclidiana, tenemos que:
#
# Para $j = 0$,
#
#
# \begin{equation}
# \theta_0 :=  - \alpha \frac{\partial J(\theta_0, \theta_1,...\theta_j...,\theta_n)}{\partial \theta_0} = \frac{1}{m}\alpha \sum_{i=1}^m (\theta_j X_j^i - \hat{y}^{(i)}) 1
# \end{equation}
#
#
#
# Para $0<j<n $
#
# \begin{equation}
# \theta_j :=  - \alpha \frac{\partial J(\theta_0, \theta_1,...\theta_j...,\theta_n)}{\partial \theta_j} = \frac{1}{m} \alpha\sum_{i=1}^m (\theta_{j} X_j^i - \hat{y}^{(i)}) X_j^i = \frac{1}{m} \alpha \sum_{i=1}^m \Lambda_i X_j^i
# \end{equation}
#
# donde $X_j$ es el j-ésimo vector de entrenamiento.
#
# Lo  anterior puede ser generalizado como sigue, teniendo presente que $X_0 = \vec{1}$
#
#
# Para $0\leq j<n$,
#
# \begin{equation}
# \theta_j :=  - \alpha \frac{\partial J(\theta_0, \theta_1,...\theta_j...,\theta_n)}{\partial \theta_j} = \frac{1}{m} \alpha \sum_{i=1}^m \Lambda_i X_j^i = \frac{1}{m} \alpha (\Lambda X^T)_j
# \end{equation}
#
#
#
# # Vectorizando el grandiente descendente, tenemos que:
# \begin{equation}
# \nabla J= \frac{1}{m} \Lambda X^T
# \end{equation}
#
# Con dimensión $(1, n+1)$. Luego:
#
# \begin{equation}
# \Theta=\Theta-\alpha \nabla J
# \end{equation}

# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %% [markdown]
# # Laboratorio 04
#
# Objetivo: Programar una regresión multivariada
#
#
# 1. Para simular un conjunto de características $x_1$ , $x_2$,..., $x_n$ trabajaremos en la primera parte con dos características de datos aleatorios que presentan un plano y mostraremos que los párametros optimizados se corresponden con el valor esperado.
#
# - Definir la ecuación  $y = 2.1*x_1 - 3.1*x_2$, y generar números aleatorios que pertenecen al plano.
#
# - Realizar un diagrama 3D de los puntos generados aleatoriamente.

# %%
# Data
M = 100
x1 = np.random.uniform(-1,1, M)
x2 = np.random.uniform(-1,1, M)
y = 2.1*x1 - 3.1*x2

# Gráfico
X1, X2 = np.meshgrid(np.linspace(-1,1,M), np.linspace(-1,1,M))
Y = 2.1*X1 - 3.1*X2

# fig = go.Figure(go.Surface(x=X1, y=X2, z=Y))
# fig.add_trace(go.Scatter3d(x=x1, y=x2, z=y, mode='markers', marker=dict(size=4, color='white')))
# fig.show()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# ax.plot_surface(X=X1, Y=X2, Z=Y, cmap='plasma', alpha=0.005)
surf = ax.plot_surface(X1, X2, Y, cmap='plasma', alpha=0.7, rstride=1, cstride=1, edgecolor='none')
ax.scatter(x1, x2, y, c='black')
ax.view_init(elev=15, azim=120)

ax.set_xlabel(r'$X_1$')
ax.set_ylabel(r'$X_2$')
ax.set_zlabel(r'$Y(X_1, X_2)$')

fig.tight_layout()

# %% [markdown]
# Nuestro objetivo será encontrar los valores $\theta_0 = 0, \theta_1=2.1, \theta_2=-3.1$ que mejor ajustan el plano, empleando cálculos vectorizados.
#
# 2. Inicializar conjunto de parámetros $\Theta$ de dimensión $(n+1, 1)$, de manera aleatoria.
#
# 3. Construir la matrix X con dimensiones $(n+1, m)$, $m$ es el numero de datos de entrenamiento y $n$ el número de caracteristicas.
#
# 4. Calcular la función de coste(revise cuidosamente las dimensiones de cada matriz):
#
#   - $h = \Theta^{T} X \quad\quad [1 \times m]$
#   - $\Lambda= (h -Y) \quad\quad [1 \times m] $
#   - $\Lambda*= (h -Y)^2$
#   - $\Lambda= [\Lambda_1,\Lambda_2, ...,\Lambda_m] \quad\quad [1 \times m]$
#   - $J = \frac{1}{2m} \sum_{i}^m \Lambda_i $
#
# 5. Aplicar el gradiente descendente:
#   - Encontrar el gradiente.
#     $\nabla J = \frac{1}{m} \Lambda X^T \quad\quad 1 \times (n+1)$
#
#   - Actualizar los nuevos parametros:
#     $\Theta_{n+1}=\Theta_{n}-\alpha\nabla J$
#
#
# 6. Iterar para encontrar los valores $\Theta$ que se ajustan el plano.

# %%
class Regresion_Multilineal():
  # Atributos: X, Y, Theta, h, J

  # Constructor
  def __init__(self, X, Y, Theta):
    # Atributos de la instancia (self) de la clase
    self.X = X    # (n+1) x m
    self.Y = Y    # 1 x m
    self.Theta = Theta    # (n+1) x 1

    Nfeatures = X.shape[0]
    # self.Theta = np.random.random(Nfeatures).reshape(Nfeatures, 1)

  # Métodos propios
  def modelo(self):
    self.H = self.Theta.T@self.X    # 1 x m

  def costo_euclidiano(self):
    self.J = 0.5*np.mean((self.H - self.Y)**2)

  # Método de minimización: Gradiente descendente
  # def update_params(self, learning_rate):
  #   gradJ = ((self.H - self.Y))@self.X.T
  #   self.Theta = self.Theta - learning_rate*gradJ

  def fit(self, learning_rate):
    eps = 1.0e-8
    m = self.X.shape[1]

    i = 0
    while True:
      self.modelo()
      self.costo_euclidiano()

      # Minimización del gradiente
      gradJ = 1/m*(self.H - self.Y)@self.X.T
      i += 1
      if np.linalg.norm(gradJ) < eps:
        break

      self.Theta = self.Theta - learning_rate*gradJ.T
    return i

# %%
M = 100
x1 = np.random.uniform(-1,1, M)
x2 = np.random.uniform(-1,1, M)
y = 2.1*x1 - 3.1*x2

# Preparación de las entradas de la clase (dimensionalidad)
X = np.array([np.ones(M), x1, x2])
Y = y.reshape(1, M)

# Inicialización de los parámetros
Nfeatures = X.shape[0]
Theta = np.random.random(Nfeatures).reshape(Nfeatures, 1)

# Probando diferentes tasas de aprendizaje
alphas = [0.001, 0.01, 0.1, 0.5]

print(f"Solución θ analítica: {[0, 2.1, -3.1]} que minimiza al Costo Euclidiano")
print("=========================================================================")

for alpha in alphas:
  print(f'\nTasa de aprendizaje: α = {alpha}')

  rml = Regresion_Multilineal(X, Y, Theta)
  Niter = rml.fit(alpha)

  print(f'* El valor mínimo del Costo Euclidiano se da cuando en θ: {rml.Theta.T}. \n\t* Iteraciones realizadas {Niter}\n')
# Out:
# Solución θ analítica: [0, 2.1, -3.1] que minimiza al Costo Euclidiano
# ...
#
# Tasa de aprendizaje: α = 0.001
# * El valor mínimo del Costo Euclidiano se da cuando en θ: [[-4.79499906e-09  2.09999998e+00 -3.09999998e+00]].
# 	* Iteraciones realizadas 53430
#
#
# Tasa de aprendizaje: α = 0.01
# * El valor mínimo del Costo Euclidiano se da cuando en θ: [[-4.78505873e-09  2.09999998e+00 -3.09999998e+00]].
# 	* Iteraciones realizadas 5336
#
#
# Tasa de aprendizaje: α = 0.1
# * El valor mínimo del Costo Euclidiano se da cuando en θ: [[-4.77841128e-09  2.09999998e+00 -3.09999998e+00]].
# 	* Iteraciones realizadas 526
#
#
# Tasa de aprendizaje: α = 0.5
# * El valor mínimo del Costo Euclidiano se da cuando en θ: [[-4.06334395e-09  2.09999999e+00 -3.09999998e+00]].
# 	* Iteraciones realizadas 99

# %% [markdown]
# **Observaciones:**
#
# * Si el gradiente de la función de costo no se divide por $m$, que es el número de datos por cada característica, entonces este tiende a valores muy grandes y aparecen errores de overflow.
#
#   ```Python
#   /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:118: RuntimeWarning: overflow encountered in reduce
#     ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#   <ipython-input-75-59c6dc506713>:18: RuntimeWarning: overflow encountered in square
#     self.J = 0.5*np.mean((self.H - self.Y)**2)
#   <ipython-input-75-59c6dc506713>:41: RuntimeWarning: overflow encountered in matmul
#     gradJ = (self.H - self.Y)@self.X.T
#   <ipython-input-75-59c6dc506713>:41: RuntimeWarning: invalid value encountered in matmul
#     gradJ = (self.H - self.Y)@self.X.T
#   <ipython-input-75-59c6dc506713>:46: RuntimeWarning: invalid value encountered in subtract
#     self.Theta = self.Theta - learning_rate*gradJ.T
#   ```
#
# * Vemos que cuando la tasa de aprendizaje crece, el gradiente descendente converge más rápido a la solución mínima de la función de costo, corriendo menos cantidad de iteraciones en el ciclo.
