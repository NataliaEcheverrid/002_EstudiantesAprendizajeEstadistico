# %% [markdown]
# # Laboratorio
# 1. Para el dataset make a moon de sklearn, construir un modelo de una red neuronal con keras para clasificar los datos.

# %%
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam

# %%
# Generar un dataset con dos clases en forma de luna creciente
X, y = make_moons(n_samples=1000, noise=0.2, random_state=42)

# Dividir los datos en conjuntos de entrenamiento (70%) y prueba (30%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalizar los datos para que todas las características tengan la misma escala
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)  # Ajustar el escalador en los datos de entrenamiento
X_test = scaler.transform(X_test)       # Aplicar la misma transformación a los datos de prueba

# Crear el modelo de red neuronal secuencial
model = Sequential([
    Input(shape=(2,)),                   # La entrada tiene 2 características (x, y)
    Dense(16, activation='relu'),        # Capa oculta con 16 neuronas y función de activación ReLU
    Dense(8, activation='relu'),         # Otra capa oculta con 8 neuronas
    Dense(1, activation='sigmoid')       # Capa de salida con una neurona y activación sigmoide (para clasificación binaria)
])

# Compilar el modelo con el optimizador Adam y una función de pérdida binaria
model.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo en el conjunto de entrenamiento y validarlo con el conjunto de prueba
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32, verbose=1)

# Evaluar el rendimiento del modelo en los datos de prueba
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Pérdida en test: {loss:.4f}, Precisión en test: {accuracy:.4f}")
# Out:
# Epoch 1/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7879 - loss: 0.5459 - val_accuracy: 0.8733 - val_loss: 0.3431
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8700 - loss: 0.3317 - val_accuracy: 0.8900 - val_loss: 0.2718
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8699 - loss: 0.2969 - val_accuracy: 0.9000 - val_loss: 0.2377
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8834 - loss: 0.2709 - val_accuracy: 0.9200 - val_loss: 0.2000
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9308 - loss: 0.2040 - val_accuracy: 0.9467 - val_loss: 0.1494
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9447 - loss: 0.1693 - val_accuracy: 0.9633 - val_loss: 0.1166
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9528 - loss: 0.1341 - val_accuracy: 0.9700 - val_loss: 0.1018
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9643 - loss: 0.0996 - val_accuracy: 0.9400 - val_loss: 0.1337
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9378 - loss: 0.1288 - val_accuracy: 0.9567 - val_loss: 0.1042
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9728 - loss: 0.0968 - val_accuracy: 0.9767 - val_loss: 0.0676
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9663 - loss: 0.0895 - val_accuracy: 0.9800 - val_loss: 0.0724
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9716 - loss: 0.0850 - val_accuracy: 0.9833 - val_loss: 0.0592
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9707 - loss: 0.0906 - val_accuracy: 0.9800 - val_loss: 0.0717
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9731 - loss: 0.0798 - val_accuracy: 0.9633 - val_loss: 0.0829
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9609 - loss: 0.1063 - val_accuracy: 0.9633 - val_loss: 0.0835
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9707 - loss: 0.0888 - val_accuracy: 0.9767 - val_loss: 0.0671
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9617 - loss: 0.0846 - val_accuracy: 0.9800 - val_loss: 0.0511
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9738 - loss: 0.0735 - val_accuracy: 0.9600 - val_loss: 0.0782
# Epoch 19/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9722 - loss: 0.0817 - val_accuracy: 0.9800 - val_loss: 0.0570
# Epoch 20/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9798 - loss: 0.0639 - val_accuracy: 0.9800 - val_loss: 0.0613
# Epoch 21/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9648 - loss: 0.0836 - val_accuracy: 0.9800 - val_loss: 0.0565
# Epoch 22/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9629 - loss: 0.0917 - val_accuracy: 0.9800 - val_loss: 0.0666
# Epoch 23/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9672 - loss: 0.0899 - val_accuracy: 0.9833 - val_loss: 0.0464
# Epoch 24/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9579 - loss: 0.1190 - val_accuracy: 0.9833 - val_loss: 0.0494
# Epoch 25/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9705 - loss: 0.0751 - val_accuracy: 0.9767 - val_loss: 0.0765
# Epoch 26/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9652 - loss: 0.0863 - val_accuracy: 0.9567 - val_loss: 0.0816
# Epoch 27/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9716 - loss: 0.0703 - val_accuracy: 0.9800 - val_loss: 0.0550
# Epoch 28/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9731 - loss: 0.0791 - val_accuracy: 0.9533 - val_loss: 0.1047
# Epoch 29/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9815 - loss: 0.0658 - val_accuracy: 0.9800 - val_loss: 0.0504
# Epoch 30/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9659 - loss: 0.0954 - val_accuracy: 0.9567 - val_loss: 0.0746
# Epoch 31/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9685 - loss: 0.0643 - val_accuracy: 0.9600 - val_loss: 0.0817
# Epoch 32/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9776 - loss: 0.0817 - val_accuracy: 0.9600 - val_loss: 0.0775
# Epoch 33/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9695 - loss: 0.0677 - val_accuracy: 0.9733 - val_loss: 0.0651
# Epoch 34/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9647 - loss: 0.0798 - val_accuracy: 0.9800 - val_loss: 0.0523
# Epoch 35/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9729 - loss: 0.0688 - val_accuracy: 0.9667 - val_loss: 0.0705
# Epoch 36/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9791 - loss: 0.0621 - val_accuracy: 0.9667 - val_loss: 0.0685
# Epoch 37/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9729 - loss: 0.0680 - val_accuracy: 0.9733 - val_loss: 0.0595
# Epoch 38/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9715 - loss: 0.0637 - val_accuracy: 0.9833 - val_loss: 0.0468
# Epoch 39/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9700 - loss: 0.0679 - val_accuracy: 0.9867 - val_loss: 0.0478
# Epoch 40/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9839 - loss: 0.0579 - val_accuracy: 0.9567 - val_loss: 0.0847
# Epoch 41/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9631 - loss: 0.0725 - val_accuracy: 0.9867 - val_loss: 0.0498
# Epoch 42/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9658 - loss: 0.0877 - val_accuracy: 0.9767 - val_loss: 0.0563
# Epoch 43/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9673 - loss: 0.0901 - val_accuracy: 0.9833 - val_loss: 0.0490
# Epoch 44/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9763 - loss: 0.0585 - val_accuracy: 0.9567 - val_loss: 0.0816
# Epoch 45/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9642 - loss: 0.0863 - val_accuracy: 0.9800 - val_loss: 0.0482
# Epoch 46/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9747 - loss: 0.0697 - val_accuracy: 0.9567 - val_loss: 0.0959
# Epoch 47/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9771 - loss: 0.0614 - val_accuracy: 0.9567 - val_loss: 0.0968
# Epoch 48/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9719 - loss: 0.0718 - val_accuracy: 0.9867 - val_loss: 0.0617
# Epoch 49/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9684 - loss: 0.0677 - val_accuracy: 0.9733 - val_loss: 0.0652
# Epoch 50/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9749 - loss: 0.0624 - val_accuracy: 0.9733 - val_loss: 0.0674
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9873 - loss: 0.0452
# Pérdida en test: 0.0674, Precisión en test: 0.9733

# %% [markdown]
# **Datos no lineales:**
#
# make_moons genera datos distribuidos en forma de lunas crecientes, lo que significa que una solución lineal (como una regresión logística) no sería suficiente. Por ello, una red neuronal con capas ocultas y funciones no lineales (como ReLU) puede capturar mejor la complejidad del problema.
#
# **Capas ocultas ayudan a modelar la no linealidad:**
#
# La inclusión de múltiples capas densas permite que el modelo capture las complejas fronteras de decisión entre las clases.
# Por ejemplo, en este caso, dos capas ocultas con 16 y 8 neuronas respectivamente, son suficientes para separar las dos clases.
#
# **Normalización mejora la convergencia:**
#
# Escalar las características con StandardScaler mejora la eficiencia del entrenamiento, ya que los valores están en un rango consistente, ayudando a que el optimizador funcione correctamente.
#
# **Resultados del modelo:**
#
# Si la red está bien diseñada y entrenada, se puede lograr una alta precisión en los datos de prueba (habitualmente >95%), demostrando que la red neuronal puede manejar problemas de clasificación binaria no triviales.

# %% [markdown]
# 2. Para el dataset load digits, construir un modelo de red neuronal empleando keras para realizar la clasificación.

# %%
# Cargar el dataset de dígitos escritos a mano (imágenes 8x8)
digits = load_digits()
X, y = digits.data, digits.target  # X contiene las características (imágenes) y y las etiquetas (dígitos)

# Convertir las etiquetas en formato one-hot encoding para clasificación multiclase
encoder = OneHotEncoder(sparse_output=False)  # sparse_output=False para devolver un arreglo denso
y = encoder.fit_transform(y.reshape(-1, 1))  # Convertir etiquetas enteras a vectores binarios

# Dividir los datos en conjuntos de entrenamiento (70%) y prueba (30%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalizar los datos para que cada característica tenga media 0 y desviación estándar 1
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)  # Ajustar el escalador en los datos de entrenamiento
X_test = scaler.transform(X_test)       # Aplicar la misma transformación a los datos de prueba

# Crear el modelo de red neuronal secuencial
model = Sequential([
    Input(shape=(64,)),                 # La entrada tiene 64 características (8x8 píxeles aplanados)
    Dense(128, activation='relu'),      # Primera capa oculta con 128 neuronas y función de activación ReLU
    Dense(64, activation='relu'),       # Segunda capa oculta con 64 neuronas
    Dense(10, activation='softmax')     # Capa de salida con 10 neuronas (una para cada clase) y activación softmax
])

# Compilar el modelo con el optimizador Adam y una función de pérdida categórica
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Entrenar el modelo en el conjunto de entrenamiento y validarlo con el conjunto de prueba
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32, verbose=1)

# Evaluar el rendimiento del modelo en los datos de prueba
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Pérdida en test: {loss:.4f}, Precisión en test: {accuracy:.4f}")
# Out:
# Epoch 1/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.3741 - loss: 1.9853 - val_accuracy: 0.8833 - val_loss: 0.8057
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9021 - loss: 0.6096 - val_accuracy: 0.9389 - val_loss: 0.3022
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9578 - loss: 0.2449 - val_accuracy: 0.9630 - val_loss: 0.1842
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9758 - loss: 0.1407 - val_accuracy: 0.9648 - val_loss: 0.1413
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0854 - val_accuracy: 0.9722 - val_loss: 0.1153
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9932 - loss: 0.0614 - val_accuracy: 0.9722 - val_loss: 0.1005
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9976 - loss: 0.0408 - val_accuracy: 0.9759 - val_loss: 0.0936
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9953 - loss: 0.0361 - val_accuracy: 0.9759 - val_loss: 0.0835
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9986 - loss: 0.0263 - val_accuracy: 0.9759 - val_loss: 0.0839
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0210 - val_accuracy: 0.9778 - val_loss: 0.0778
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0152 - val_accuracy: 0.9778 - val_loss: 0.0754
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.9778 - val_loss: 0.0751
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.9778 - val_loss: 0.0728
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.9796 - val_loss: 0.0720
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9778 - val_loss: 0.0699
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.9778 - val_loss: 0.0700
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9796 - val_loss: 0.0697
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9778 - val_loss: 0.0682
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9796 - val_loss: 0.0692
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9815 - val_loss: 0.0681
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9815 - val_loss: 0.0682
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9815 - val_loss: 0.0674
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9796 - val_loss: 0.0675
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9815 - val_loss: 0.0672
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9815 - val_loss: 0.0670
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9815 - val_loss: 0.0668
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9815 - val_loss: 0.0668
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9815 - val_loss: 0.0666
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9833 - val_loss: 0.0672
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9833 - val_loss: 0.0673
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9815 - val_loss: 0.0668
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9833 - val_loss: 0.0667
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9833 - val_loss: 0.0668
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9833 - val_loss: 0.0666
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9815 - val_loss: 0.0669
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.9792e-04 - val_accuracy: 0.9833 - val_loss: 0.0667
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.8646e-04 - val_accuracy: 0.9833 - val_loss: 0.0669
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.6074e-04 - val_accuracy: 0.9833 - val_loss: 0.0668
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.8578e-04 - val_accuracy: 0.9833 - val_loss: 0.0670
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.6284e-04 - val_accuracy: 0.9815 - val_loss: 0.0671
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 7.1821e-04 - val_accuracy: 0.9833 - val_loss: 0.0671
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.5401e-04 - val_accuracy: 0.9833 - val_loss: 0.0669
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.1232e-04 - val_accuracy: 0.9833 - val_loss: 0.0670
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.8797e-04 - val_accuracy: 0.9852 - val_loss: 0.0672
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.7762e-04 - val_accuracy: 0.9852 - val_loss: 0.0673
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.8359e-04 - val_accuracy: 0.9833 - val_loss: 0.0677
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.8699e-04 - val_accuracy: 0.9852 - val_loss: 0.0677
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.9036e-04 - val_accuracy: 0.9852 - val_loss: 0.0676
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.1158e-04 - val_accuracy: 0.9852 - val_loss: 0.0680
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.7783e-04 - val_accuracy: 0.9852 - val_loss: 0.0679
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9881 - loss: 0.0484
# Pérdida en test: 0.0679, Precisión en test: 0.9852

# %% [markdown]
# **Clasificación multiclase con Softmax:**
#
# Este problema requiere identificar más de dos clases. Por ello, se utiliza la función de activación softmax en la capa de salida, que asigna una probabilidad a cada una de las 10 clases.
#
# **Mayor complejidad del modelo:**
#
# Las imágenes (de 8x8 píxeles) se convierten en vectores con 64 características. El modelo necesita aprender patrones más complejos, por lo que se requiere una arquitectura con más neuronas (ej., 128 en la primera capa) para capturar esta información.
#
# **Codificación One-Hot:**
#
# La salida se convierte en un formato one-hot encoding para representar las 10 clases, lo que permite que la red neuronal minimice la pérdida usando categorical_crossentropy.
#
# **Normalización sigue siendo crucial:**
#
# Similar al primer modelo, la normalización de las características mejora la estabilidad del entrenamiento, ya que las imágenes originales tienen valores en rangos diversos.
#
# **Resultados esperados:**
#
# Con una arquitectura adecuada y suficientes épocas de entrenamiento, es posible alcanzar una precisión superior al 90% en este dataset. Sin embargo, es posible que se necesite más optimización (como ajustes en las capas, regularización o aprendizaje profundo) para igualar el rendimiento de algoritmos especializados como el SVM.
